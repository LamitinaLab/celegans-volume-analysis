# %% [markdown]
# # Genotype Data Compilation
#
# This notebook compiles raw data organized by genotype/group and video into standardized CSV files with side-by-side track columns for each metric (area, length, fit, curvature, midpoint bending angle).

# %% [markdown]
# ## Setup and File Discovery
#
# Define input/output directories and helper functions to:
# - Discover date folders in `data/raw`, then genotype/group folders within each date
# - Load metadata from YAML file in each genotype folder (config.yaml or <genotype>.yaml, including the required integer-like `condition_order` used for compilation order)
# - Find video folders (0001, 0002, etc.) within each genotype
# - Gather metric CSV files (position, length, area, fit, curvature, midpoint bending angle) from each video folder
# - Compile tracks side-by-side using outer merge to handle videos with different frame counts
# - Display a summary of all loaded metadata

# %%
from pathlib import Path
import pandas as pd
import math
from numbers import Integral
import re
import sys
import yaml


# Data folder structure:
# data/raw/
#   <date_folder>/
#     [optional intermediary folders like wormlab_exports, strain folders, etc.]
#     <condition_or_group>/
#       0001/  (video folder)
#         position.csv, length.csv, area.csv, fit.csv, midpoint_bending_angle.csv
#       0002/  (another video)
#         ...
#
# data/metadata/
#   <condition>.yaml   (one YAML per condition)


# Determine project root
current_dir = Path.cwd()

if current_dir.name == "Notebooks":
    project_root = current_dir.parent
else:
    project_root = current_dir


raw_dir = project_root / "data" / "raw"
compiled_dir = project_root / "data" / "processed"
metadata_dir = project_root / "data" / "metadata"

raw_dir.mkdir(parents=True, exist_ok=True)
compiled_dir.mkdir(parents=True, exist_ok=True)

search_dir = raw_dir
out_dir = compiled_dir


print(f"Project root: {project_root}")
print(f"Looking for data in: {raw_dir}")
print(f"Looking for metadata in: {metadata_dir}")


def load_genotype_metadata(genotype_dir: Path):
    """
    Load metadata YAML for a genotype/condition folder.

    Search order:
    1. data/metadata/<condition_name>.yaml or .yml
    2. YAML file inside the condition folder itself (legacy support)

    Returns:
        dict
    """

    # Central metadata directory
    central_yaml = metadata_dir / f"{genotype_dir.name}.yaml"
    central_yml = metadata_dir / f"{genotype_dir.name}.yml"

    for candidate in (central_yaml, central_yml):
        if candidate.exists():
            try:
                with open(candidate, "r") as f:
                    metadata = yaml.safe_load(f)

                return metadata if metadata else {}

            except Exception as e:
                print(
                    f"Warning reading {candidate}: {e}",
                    file=sys.stderr
                )

    # Legacy fallback: YAML stored inside condition folder
    yaml_files = (
        list(genotype_dir.glob("*.yaml"))
        + list(genotype_dir.glob("*.yml"))
    )

    if yaml_files:
        metadata_path = yaml_files[0]

        try:
            with open(metadata_path, "r") as f:
                metadata = yaml.safe_load(f)

            return metadata if metadata else {}

        except Exception as e:
            print(
                f"Warning reading {metadata_path}: {e}",
                file=sys.stderr
            )

    return {}


def infer_metric_from_filename(csv_path: Path):
    """
    Map WormLab CSV filenames to canonical metric names.

    Supported metrics:
        position
        length
        area
        fit
        bending_angle

    Curvature is intentionally not supported and will be ignored.
    """

    bending_angle_aliases = {
        "bending_angle",
        "bending_angle_midpoint",
        "midpoint_bending_angle",
        "mid_point_bending_angle",
        "midpoint_bend_angle",
        "midpoint_angle",
        "bending_angle_mid_point",
    }

    for candidate in (csv_path.stem, csv_path.name):
        normalized = re.sub(
            r"[^a-z0-9]+",
            "_",
            candidate.lower()
        ).strip("_")

        if "position" in normalized:
            return "position"

        if "length" in normalized:
            return "length"

        if "area" in normalized:
            return "area"

        if re.search(r"(^|_)fit($|_)", normalized):
            return "fit"

        for alias in bending_angle_aliases:
            if alias in normalized:
                return "bending_angle"

    return None


def find_data_groups(dirpath: Path, date_folder=None):
    """
    Recursively find condition/group folders containing numbered
    WormLab video folders.

    Expected structure:

        data/raw/
            <date_folder>/
                <condition>/
                    0001/
                        *.csv
                    0002/
                        *.csv

    Also supports extra intermediary folders.

    Important:
    - group key = condition folder name only
    - date folder is stored separately in group_data["date"]

    Returns:
        {
            condition_name: {
                "files": [(filepath, metric, video_id), ...],
                "metadata": {...},
                "date": date_folder,
                "path": "...",
            }
        }
    """

    groups = {}

    if not dirpath.exists():
        print(
            f"Warning: Directory {dirpath} does not exist!",
            file=sys.stderr
        )
        return groups

    try:
        items = sorted(dirpath.iterdir())
    except PermissionError:
        return groups

    subdirs = [x for x in items if x.is_dir()]

    # Detect a numeric date folder directly below data/raw
    if dirpath.parent == raw_dir and dirpath.name.isdigit():
        date_folder = dirpath.name

    # A condition/group folder contains numbered video folders
    numbered_subdirs = [
        d for d in subdirs
        if d.name.isdigit()
    ]

    if numbered_subdirs:

        has_csvs = any(
            any(video_dir.glob("*.csv"))
            for video_dir in numbered_subdirs
        )

        if has_csvs:

            metadata = load_genotype_metadata(dirpath)

            files_list = []

            for video_dir in numbered_subdirs:
                video_id = video_dir.name

                for csv_file in video_dir.glob("*.csv"):

                    metric = infer_metric_from_filename(csv_file)

                    if metric is None:
                        # Curvature and any other unsupported files
                        # are intentionally ignored.
                        continue

                    files_list.append(
                        (csv_file, metric, video_id)
                    )

            # Condition name only — do not prepend the date
            group_key = dirpath.name

            groups[group_key] = {
                "files": files_list,
                "metadata": metadata,
                "date": date_folder,
                "path": str(dirpath),
            }

            return groups

    # Recurse through intermediary folders if needed
    for subdir in subdirs:

        sub_groups = find_data_groups(
            subdir,
            date_folder=date_folder
        )

        groups.update(sub_groups)

    return groups


def condition_ordered_group_keys(groups):
    """Validate YAML condition_order and return group keys in that order."""
    order_records = []
    missing_groups = []

    for key, group_data in groups.items():
        metadata = group_data.get("metadata") or {}
        raw_order = metadata.get("condition_order")

        if raw_order is None:
            missing_groups.append(key)
            continue

        if isinstance(raw_order, bool):
            raise ValueError(
                f"condition_order for group {key!r} must be an integer, "
                "not boolean."
            )

        try:
            numeric_order = float(raw_order)
        except (OverflowError, TypeError, ValueError) as exc:
            raise ValueError(
                f"condition_order for group {key!r} must be numeric and finite; "
                f"received {raw_order!r}."
            ) from exc

        if not math.isfinite(numeric_order):
            raise ValueError(
                f"condition_order for group {key!r} must be finite; "
                f"received {raw_order!r}."
            )

        if not isinstance(raw_order, Integral):
            raise ValueError(
                f"condition_order for group {key!r} must be an integer; "
                f"received {raw_order!r} ({type(raw_order).__name__})."
            )

        condition_order = int(raw_order)
        if condition_order < 0:
            raise ValueError(
                f"condition_order for group {key!r} must be >= 0; "
                f"received {condition_order}."
            )

        experiment_key = (
            metadata.get("experiment_id"),
            group_data.get("date"),
        )
        order_records.append((experiment_key, condition_order, key))

    if missing_groups:
        raise ValueError(
            "Missing condition_order metadata for groups: "
            f"{missing_groups}"
        )

    seen_orders = {}
    records_by_experiment = {}
    for experiment_key, condition_order, key in order_records:
        uniqueness_key = (experiment_key, condition_order)
        if uniqueness_key in seen_orders:
            raise ValueError(
                "Duplicate condition_order within experiment "
                f"{experiment_key!r}: groups {seen_orders[uniqueness_key]!r} "
                f"and {key!r} both use {condition_order}."
            )
        seen_orders[uniqueness_key] = key
        records_by_experiment.setdefault(experiment_key, []).append(
            (condition_order, key)
        )

    for experiment_key, experiment_records in records_by_experiment.items():
        control_groups = [
            key
            for condition_order, key in experiment_records
            if condition_order == 0
        ]
        if len(control_groups) != 1:
            raise ValueError(
                "Exactly one active group per experiment must have "
                "condition_order == 0. "
                f"Experiment {experiment_key!r} has {len(control_groups)}: "
                f"{control_groups}."
            )

    order_records.sort(key=lambda item: (str(item[0]), item[1]))
    return [key for _, _, key in order_records]


# ------------------------------------------------------------
# Inspect available files and groups
# ------------------------------------------------------------

groups = find_data_groups(search_dir)
ordered_group_keys = condition_ordered_group_keys(groups)

print(f"\nRaw data dir: {search_dir}")
print(f"Output dir: {out_dir}")

print(
    f"Found {len(groups)} data groups: "
    f"{ordered_group_keys}"
)

print("\nMetadata summary:")

for key in ordered_group_keys:

    group_data = groups[key]
    metadata = group_data["metadata"]
    file_count = len(group_data["files"])
    date = group_data.get("date")
    path_info = group_data.get("path", "unknown")

    print(
        f"  {key} "
        f"(date: {date}, path: {path_info}): "
        f"{file_count} files"
    )

    if metadata:

        for mkey, value in metadata.items():
            print(f"    {mkey}: {value}")

    else:
        print("    (no YAML file found)")
# Out:
# Project root: r:\Users\Todd\VScode folders\celegans-volume-analysis
# Looking for data in: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\raw
# Looking for metadata in: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\metadata
#
# Raw data dir: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\raw
# Output dir: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed
# Found 11 data groups: ['21', '150', '250', '350', '450', '550', '650', '750', '850', '950', '1050']
#
# Metadata summary:
#   21 (date: 260311, path: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\21): 28 files
#     assay: volume
#     experiment_id: 260311
#     assay_date: 260311
#     analysis_date: 260828
#     condition_order: 0
#     genotype: +/+
#     strain: N2
#     background: N2
#     outcrosses: unknown
#     age: Day 1
#     treatment: none
#     treatment_level: None
#     treatment_level_unit: None
# ...

# %%
# DEBUG: trace exactly which YAML file is being loaded for each discovered group

import yaml
from pathlib import Path

print(f"metadata_dir = {metadata_dir}")
print(f"metadata_dir.exists() = {metadata_dir.exists()}")
print()

for group_name, group_data in sorted(groups.items()):
    group_path = Path(group_data.get("path", ""))
    
    # Use the actual condition folder name rather than the group key,
    # because older versions of find_data_groups() may prepend the date.
    condition_name = group_path.name if group_path else group_name
    
    candidate = metadata_dir / f"{condition_name}.yaml"
    
    print(f"{group_name}:")
    print(f"  condition_name = {condition_name}")
    print(f"  checking = {candidate}")
    print(f"  exists = {candidate.exists()}")
    
    if candidate.exists():
        try:
            with open(candidate, "r") as f:
                data = yaml.safe_load(f) or {}
            
            print(f"  experimenter = {data.get('experimenter')}")
            print(f"  experiment_id = {data.get('experiment_id')}")
            print(f"  genotype = {data.get('genotype')}")
            print(f"  strain = {data.get('strain')}")
        
        except Exception as e:
            print(f"  ERROR reading YAML: {e}")
    
    print()
# Out:
# metadata_dir = r:\Users\Todd\VScode folders\celegans-volume-analysis\data\metadata
# metadata_dir.exists() = True
#
# 1050:
#   condition_name = 1050
#   checking = r:\Users\Todd\VScode folders\celegans-volume-analysis\data\metadata\1050.yaml
#   exists = True
#   experimenter = TL
#   experiment_id = 260311
#   genotype = +/+
#   strain = N2
#
# 150:
#   condition_name = 150
#   checking = r:\Users\Todd\VScode folders\celegans-volume-analysis\data\metadata\150.yaml
#   exists = True
#   experimenter = TL
#   experiment_id = 260311
#   genotype = +/+
#   strain = N2
#
# 21:
#   condition_name = 21
#   checking = r:\Users\Todd\VScode folders\celegans-volume-analysis\data\metadata\21.yaml
#   exists = True
#   experimenter = TL
#   experiment_id = 260311
#   genotype = +/+
#   strain = N2
#
# 250:
#   condition_name = 250
#   checking = r:\Users\Todd\VScode folders\celegans-volume-analysis\data\metadata\250.yaml
#   exists = True
#   experimenter = TL
#   experiment_id = 260311
# ...

# %% [markdown]
# ## Compile and Export Results
#
# Process all discovered genotypes and metrics:
# - Compile CSVs for each metric (area, length, fit, curvature, midpoint bending angle)
# - Generate one output file per genotype per metric
# - Create a compilation summary CSV listing all compiled files and their locations
# - Create a genotype metadata summary CSV combining all config.yaml metadata (strain, genotype, NaCl, frame rate, pixel resolution, notes, etc.)

# %%
def compile_tracks_side_by_side(key: str, files: list, metric: str, out_dir: Path, metadata=None):
    """
    Compile all files for a given metric side-by-side.

    Parameters:
    - key: group identifier
    - files: list of tuples (filepath, metric_name, video_id)
    - metric: metric name to compile
              (e.g. 'area', 'length', 'fit', 'position', 'bending_angle')
    - out_dir: output directory Path
    - metadata: optional metadata dict

    Returns:
    - output file path if successful, None otherwise
    """
    metric_target = metric.lower()

    # Filter files for this metric (supports legacy metric tags and filename inference)
    metric_files = []
    for filepath, metric_name, video_id in files:
        inferred_metric = infer_metric_from_filename(filepath)
        if inferred_metric is None and metric_name:
            inferred_metric = str(metric_name).lower()
        if inferred_metric == metric_target:
            metric_files.append((filepath, inferred_metric, video_id))
    
    if not metric_files:
        print(f"No files for {key} / {metric}")
        return None

    # Some metrics can have multiple files per video.
    # Track counts so we can disambiguate output column prefixes when needed.
    files_per_video = {}
    for filepath, _, video_id in metric_files:
        files_per_video[video_id] = files_per_video.get(video_id, 0) + 1
    
    def read_with_header(path):
        try:
            df = pd.read_csv(path, skiprows=1)
        except Exception as e:
            print(f"ERROR reading {path}: {e}", file=sys.stderr)
            raise
        return df

    def _safe_name(text: str):
        cleaned = re.sub(r'[^0-9a-zA-Z]+', '_', text).strip('_')
        return cleaned or 'file'
    
    # Phase 1: collect all valid dataframes with renamed track columns
    valid_dfs = []
    for filepath, _, video_id in sorted(metric_files):
        df = read_with_header(filepath)
        
        if 'Frame' not in df.columns or 'Time' not in df.columns:
            print(f"Skipping {filepath} (missing Frame/Time)", file=sys.stderr)
            continue

        # Prefix track columns with video_id. If multiple files exist for the same
        # video+metric, include a filename tag to avoid duplicate columns.
        if files_per_video.get(video_id, 0) > 1:
            file_tag = _safe_name(filepath.stem)
            prefix = f"{video_id}_{file_tag}"
        else:
            prefix = video_id

        cols = [c for c in df.columns if c not in ['Frame', 'Time']]
        rename_map = {c: f"{prefix}_{c}" for c in cols}
        df = df.rename(columns=rename_map)
        valid_dfs.append(df)

    if not valid_dfs:
        print(f"No valid data for {key}/{metric}", file=sys.stderr)
        return None

    # Phase 2: check for frame-count differences at the end of recordings
    last_frames = [int(df['Frame'].iloc[-1]) for df in valid_dfs]
    min_last_frame = min(last_frames)
    max_last_frame = max(last_frames)
    frame_diff = max_last_frame - min_last_frame

    if frame_diff > 2:
        print(f"Warning: {key}/{metric}: videos differ by {frame_diff} frames at end "
              f"(trimming to frame {min_last_frame})")

    # Phase 3: merge all dataframes on Frame using an inner join.
    # This naturally drops any trailing frames not present in every file
    # without needing explicit trimming.
    out_df = valid_dfs[0]
    for df in valid_dfs[1:]:
        track_cols = [c for c in df.columns if c not in ['Frame', 'Time']]
        out_df = pd.merge(out_df, df[['Frame'] + track_cols], on='Frame', how='inner')

    if out_df.empty:
        print(f"No valid data for {key}/{metric}", file=sys.stderr)
        return None
    
    # Create output filename
    out_path = out_dir / f"{key}_compiled_{metric}.csv"
    out_df.to_csv(out_path, index=False)
    print(f"Wrote {out_path} (shape={out_df.shape})")
    return out_path

# %%
# Compile all discovered groups and write outputs
# One file per group per metric

from pathlib import Path
import pandas as pd

if 'compile_tracks_side_by_side' not in globals():
    raise RuntimeError(
        "compile_tracks_side_by_side is not defined. "
        "Run Cell 4 (Compile and Export Results function cell) first."
    )

if 'groups' not in globals() or not isinstance(groups, dict):
    if 'find_data_groups' in globals():
        print("`groups` not found. Discovering data groups now...")
        groups = find_data_groups(search_dir)
    else:
        raise RuntimeError(
            "groups is not defined and find_data_groups is unavailable. "
            "Run Cell 3 (Setup and File Discovery) first."
        )

if 'out_dir' not in globals():
    current_dir = Path.cwd()
    project_root = (
        current_dir.parent
        if current_dir.name == "Notebooks"
        else current_dir
    )

    out_dir = project_root / "data" / "processed"
    out_dir.mkdir(parents=True, exist_ok=True)

results = {}
compilation_rows = []
metadata_rows = []

# Curvature intentionally excluded from this analysis
metrics = [
    'position',
    'area',
    'length',
    'fit',
    'bending_angle',
]

if not groups:
    print("No data groups found. Nothing to compile.")

ordered_group_keys = condition_ordered_group_keys(groups)

for key in ordered_group_keys:

    group_data = groups[key]
    files = group_data['files']
    metadata = group_data['metadata']
    date_folder = group_data.get('date')

    # Use genotype from group_data if explicitly provided;
    # otherwise fall back to the condition/group key.
    genotype = metadata.get('genotype', key)

    results[key] = {}

    # Record metadata for summary
    metadata_summary = {
        'key': key,
        'genotype': genotype,
        'date': date_folder,
    }

    metadata_summary.update({
        metadata_key: metadata_value
        for metadata_key, metadata_value in metadata.items()
    })
    metadata_rows.append(metadata_summary)

    # Compile each supported metric
    for metric in metrics:

        p = compile_tracks_side_by_side(
            key,
            files,
            metric,
            out_dir,
            metadata=metadata,
        )

        if p:
            print(
                f"Saved compiled file for "
                f"{key} metric {metric}: {p}"
            )

            compilation_rows.append({
                'key': key,
                'genotype': genotype,
                'date': date_folder,
                'metric': metric,
                'compiled_path': str(p),
            })

            results[key][metric] = p

        else:
            print(f"No {metric} data saved for {key}")


# ------------------------------------------------------------
# Create compilation summary
# ------------------------------------------------------------

summary = pd.DataFrame(compilation_rows)
display(summary)

summary_path = out_dir / 'compilation_summary.csv'
summary.to_csv(summary_path, index=False)

print(f"\nWrote compilation summary to {summary_path}")


# ------------------------------------------------------------
# Create metadata summary
# ------------------------------------------------------------

metadata_df = pd.DataFrame(metadata_rows)

metadata_path = out_dir / 'genotype_metadata.csv'
metadata_df.to_csv(metadata_path, index=False)

print(f"Wrote genotype metadata to {metadata_path}")
print(f"\nMetadata columns: {list(metadata_df.columns)}")
# Out:
# ...
# Wrote r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_position.csv (shape=(8395, 44))
# Saved compiled file for 21 metric position: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_position.csv
# ...
# Wrote r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_area.csv (shape=(8395, 23))
# Saved compiled file for 21 metric area: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_area.csv
# ...
# Wrote r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_length.csv (shape=(8395, 23))
# Saved compiled file for 21 metric length: r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_length.csv
# ...
# Wrote r:\Users\Todd\VScode folders\celegans-volume-analysis\data\processed\21_compiled_fit.csv (shape=(8395, 23))
# ...

# %% [markdown]
# ## Notes
#
# **Data structure:**
# ```
# data/raw/
#   <date_folder>/                     (e.g., 260311/)
#     <genotype_or_intermediary>/
#       <condition>/                   (e.g., 150/, 250/)
#         0001/                        (video folder)
#           area.csv
#           length.csv
#           position.csv
#           fit.csv
#           curvature.csv              (one file per animal for thrashing analysis in Notebook 02)
#           midpoint_bending_angle.csv
#         0002/                        (another video)
#           ...
#
# data/metadata/
#   150.yaml                           (one YAML per condition, named to match the condition folder)
#   250.yaml
#   ...
# ```
#
# **Output files:**
# - `<group_key>_compiled_<metric>.csv`: Compiled metric data with tracks from all videos side-by-side
# - `compilation_summary.csv`: List of all compiled files with group key and paths
# - `genotype_metadata.csv`: Metadata from all YAML files with group information, ordered by validated `condition_order` (the helper field is not exported)
#
# **Column naming:**
# - Track columns in output are prefixed with video_id to distinguish videos (e.g., `0001_track_name`)
# - When a video has multiple files for the same metric, the filename is included in the prefix (e.g., `0001_midpoint_bending_angle_<col>`)
#
# **YAML metadata lookup (search order):**
# 1. `data/metadata/<condition_folder_name>.yaml`  — centralised location (preferred)
# 2. Any `*.yaml` / `*.yml` file inside the condition folder itself (legacy fallback)
#
# **Metric CSV naming (supported):**
# - Legacy metric filenames: `area.csv`, `length.csv`, `position.csv`, `fit.csv`, `curvature.csv`, `bending_angle.csv`
# - Midpoint bending-angle filenames are also recognized through aliases such as `midpoint_bending_angle`, `mid_point_bending_angle`, `midpoint_bend_angle`, `bending_angle_midpoint`, and WormLab batch exports like `BatchExport.csv_Bending Angle - Mid-Point.csv`
# - Curvature filenames are recognized through aliases such as `curvature_plot`, `midpoint_curvature`, `body_curvature`, and `spine_curvature`
# - Metric detection is case-insensitive and matches metric tokens anywhere in the filename after normalizing spaces and punctuation
# **Notebook 02 thrashing input:**
# - Curvature analysis uses individual-animal curvature traces from each video folder (one curvature CSV per animal)
# - Compiled curvature outputs preserve one prefixed curvature trace per animal/video for downstream thrashing-rate calculation
#
# **Handling different video lengths:**
# - If videos have different numbers of frames, the compiled file includes ALL frames from ALL videos
# - Track values are filled with NaN where a video doesn't have data for that frame
#
# **Backward compatibility:**
# - The code also supports YAML files placed directly in the condition folder (legacy)
