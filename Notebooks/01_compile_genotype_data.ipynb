# %% [markdown]
# # Genotype Data Compilation
#
# This notebook compiles raw data organized by genotype/group and video into standardized CSV files with side-by-side track columns for each metric (area, length, position, fit, curvature).

# %% [markdown]
# ## Setup and File Discovery
#
# Define input/output directories and helper functions to:
# - Discover date folders in `data/raw`, then genotype/group folders within each date
# - Load metadata from YAML file in each genotype folder (config.yaml or <genotype>.yaml, containing strain, genotype, NaCl concentration, frame rate, pixel resolution, notes)
# - Find video folders (0001, 0002, etc.) within each genotype
# - Gather metric CSV files (position, length, area, fit, curvature) from each video folder
# - Compile tracks side-by-side using outer merge to handle videos with different frame counts
# - Display a summary of all loaded metadata

# %%
from pathlib import Path
import pandas as pd
import re
import sys
import yaml

# Data folder structure:
# data/raw/
#   <date_folder>/
#     [optional intermediary folders like wormlab_exports, strain folders, etc.]
#     <condition_or_group>/
#       0001/  (video folder)
#         position.csv, length.csv, area.csv, fit.csv, curvature.csv
#       0002/  (another video)
#         ...
# data/metadata/
#   <condition>.yaml   (one YAML per condition, e.g. 150.yaml, 250.yaml)

# Determine project root (go up one level if we're in Notebooks folder)
current_dir = Path.cwd()
if current_dir.name == "Notebooks":
    project_root = current_dir.parent
else:
    project_root = current_dir

raw_dir = project_root / "data" / "raw"
compiled_dir = project_root / "data" / "processed"
metadata_dir = project_root / "data" / "metadata"   # centralised YAML files
raw_dir.mkdir(parents=True, exist_ok=True)
compiled_dir.mkdir(parents=True, exist_ok=True)

search_dir = raw_dir
out_dir = compiled_dir

print(f"Project root: {project_root}")
print(f"Looking for data in: {raw_dir}")
print(f"Looking for metadata in: {metadata_dir}")


def load_genotype_metadata(genotype_dir: Path):
    """Load metadata YAML for a genotype/condition folder.

    Search order:
    1. Central metadata_dir: looks for <folder_name>.yaml  (e.g. data/metadata/150.yaml)
    2. Fallback: any *.yaml / *.yml file inside genotype_dir itself (legacy)
    Returns a dict with metadata, or empty dict if no file is found.
    """
    # 1. Central metadata directory — match by condition folder name
    central_yaml = metadata_dir / f"{genotype_dir.name}.yaml"
    central_yml  = metadata_dir / f"{genotype_dir.name}.yml"
    for candidate in (central_yaml, central_yml):
        if candidate.exists():
            try:
                with open(candidate, 'r') as f:
                    metadata = yaml.safe_load(f)
                return metadata if metadata else {}
            except Exception as e:
                print(f'Warning reading {candidate}: {e}', file=sys.stderr)

    # 2. Fallback: YAML file inside the genotype folder
    yaml_files = list(genotype_dir.glob('*.yaml')) + list(genotype_dir.glob('*.yml'))
    if yaml_files:
        metadata_path = yaml_files[0]
        try:
            with open(metadata_path, 'r') as f:
                metadata = yaml.safe_load(f)
            return metadata if metadata else {}
        except Exception as e:
            print(f'Warning reading {metadata_path}: {e}', file=sys.stderr)

    return {}


def infer_metric_from_filename(csv_path: Path):
    """Map CSV filenames to canonical metric names.

    Supports both old naming (area.csv, fit.csv, length.csv, position.csv, curvature.csv)
    and batch-export naming (e.g., BatchExport.csv_Position.csv, BatchExport.csv_Curvature.csv).
    """
    metric_pattern = re.compile(
        r'(^|[^a-z])(position|length|area|fit|curvature|curvaturemap|curvature_map|spinecurvature|spine_curvature|wormspinecurvature|worm_spine_curvature)([^a-z]|$)',
        re.IGNORECASE,
    )

    metric_aliases = {
        'curvaturemap': 'curvature',
        'curvature_map': 'curvature',
        'spinecurvature': 'curvature',
        'spine_curvature': 'curvature',
        'wormspinecurvature': 'curvature',
        'worm_spine_curvature': 'curvature',
    }

    for candidate in (csv_path.stem, csv_path.name):
        match = metric_pattern.search(candidate.lower())
        if match:
            metric = match.group(2).lower()
            return metric_aliases.get(metric, metric)

    return None


def find_data_groups(dirpath: Path, prefix: str = ""):
    """
    Recursively find data groups by looking for folders with:
    - Numbered video subdirectories containing CSVs

    Handles arbitrary nesting levels (like wormlab_exports, strain folders, etc.).
    Returns a dict: {group_key: {'files': [(filepath, metric, video_id), ...], 'metadata': {...}, 'date': date_folder}}
    """
    groups = {}
    
    if not dirpath.exists():
        print(f"Warning: Directory {dirpath} does not exist!", file=sys.stderr)
        return groups
    
    try:
        items = sorted(dirpath.iterdir())
    except PermissionError:
        return groups
    
    subdirs = [x for x in items if x.is_dir()]
    
    # If this folder has numbered video subdirectories, it's a data group
    numbered_subdirs = [d for d in subdirs if d.name.isdigit()]
    
    if numbered_subdirs:
        # Check if any numbered subdir contains CSVs
        has_csvs = any((d / f).exists() for d in numbered_subdirs for f in d.glob('*.csv'))
        
        if has_csvs:
            metadata = load_genotype_metadata(dirpath)
            
            files_list = []
            for video_dir in numbered_subdirs:
                video_id = video_dir.name
                for f in video_dir.glob('*.csv'):
                    metric = infer_metric_from_filename(f)
                    if metric is None:
                        print(f"Skipping unrecognized metric file: {f}")
                        continue
                    files_list.append((f, metric, video_id))
            
            group_key = prefix if prefix else dirpath.name
            groups[group_key] = {
                'files': files_list,
                'metadata': metadata,
                'date': None,
                'path': str(dirpath)
            }
            return groups  # Don't recurse further into this group
    
    # Recursively search subdirectories
    for subdir in subdirs:
        new_prefix = f"{prefix}_{subdir.name}" if prefix else subdir.name
        sub_groups = find_data_groups(subdir, prefix=new_prefix)
        groups.update(sub_groups)
    
    return groups


# Inspect available files and groups
groups = find_data_groups(search_dir)
print(f'\nRaw data dir: {search_dir}')
print(f'Output dir: {out_dir}')
print(f'Found {len(groups)} data groups: {sorted(groups.keys())}')
print(f'\nMetadata summary:')
for key in sorted(groups.keys()):
    group_data = groups[key]
    metadata = group_data['metadata']
    file_count = len(group_data['files'])
    path_info = f" (path: {group_data.get('path', 'unknown')})"
    print(f'  {key}{path_info}: {file_count} files')
    if metadata:
        for mkey, value in metadata.items():
            print(f'    {mkey}: {value}')
    else:
        print(f'    (no YAML file found)')
# Out:
# Project root: c:\Users\MBF\celegans-volume-analysis
# Looking for data in: c:\Users\MBF\celegans-volume-analysis\data\raw
# Looking for metadata in: c:\Users\MBF\celegans-volume-analysis\data\metadata
#
# Raw data dir: c:\Users\MBF\celegans-volume-analysis\data\raw
# Output dir: c:\Users\MBF\celegans-volume-analysis\data\processed
# Found 11 data groups: ['260311_wormlab_exports_N2_1050', '260311_wormlab_exports_N2_150', '260311_wormlab_exports_N2_21', '260311_wormlab_exports_N2_250', '260311_wormlab_exports_N2_350', '260311_wormlab_exports_N2_450', '260311_wormlab_exports_N2_550', '260311_wormlab_exports_N2_650', '260311_wormlab_exports_N2_750', '260311_wormlab_exports_N2_850', '260311_wormlab_exports_N2_950']
#
# Metadata summary:
#   260311_wormlab_exports_N2_1050 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\1050): 50 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_150 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\150): 37 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_21 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\21): 49 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_250 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\250): 39 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_350 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\350): 34 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_450 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\450): 42 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_550 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\550): 20 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_650 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\650): 81 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_750 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\750): 31 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_850 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\850): 34 files
#     (no YAML file found)
#   260311_wormlab_exports_N2_950 (path: c:\Users\MBF\celegans-volume-analysis\data\raw\260311\wormlab_exports\N2\950): 46 files
#     (no YAML file found)

# %% [markdown]
# ## Compile and Export Results
#
# Process all discovered genotypes and metrics:
# - Compile CSVs for each metric (area, length, fit, curvature)
# - Generate one output file per genotype per metric
# - Create a compilation summary CSV listing all compiled files and their locations
# - Create a genotype metadata summary CSV combining all config.yaml metadata (strain, genotype, NaCl, frame rate, pixel resolution, notes, etc.)

# %%
def compile_tracks_side_by_side(key: str, files: list, metric: str, out_dir: Path, metadata=None):
    """
    Compile all files for a given metric side-by-side.
    
    Parameters:
    - key: group identifier
    - files: list of tuples (filepath, metric_name, video_id)
    - metric: metric name to compile (e.g., 'area', 'length', 'fit', 'curvature')
    - out_dir: output directory Path
    - metadata: optional metadata dict
    
    Returns:
    - output file path if successful, None otherwise
    """
    metric_target = metric.lower()

    # Filter files for this metric (supports legacy metric tags and filename inference)
    metric_files = []
    for filepath, metric_name, video_id in files:
        inferred_metric = infer_metric_from_filename(filepath)
        if inferred_metric is None and metric_name:
            inferred_metric = str(metric_name).lower()
        if inferred_metric == metric_target:
            metric_files.append((filepath, inferred_metric, video_id))
    
    if not metric_files:
        print(f"No files for {key} / {metric}")
        return None

    # Some metrics (especially curvature) can have multiple files per video.
    # Track counts so we can disambiguate output column prefixes when needed.
    files_per_video = {}
    for filepath, _, video_id in metric_files:
        files_per_video[video_id] = files_per_video.get(video_id, 0) + 1
    
    def read_with_header(path):
        try:
            df = pd.read_csv(path, skiprows=1)
        except Exception as e:
            print(f"ERROR reading {path}: {e}", file=sys.stderr)
            raise
        return df

    def _safe_name(text: str):
        cleaned = re.sub(r'[^0-9a-zA-Z]+', '_', text).strip('_')
        return cleaned or 'file'
    
    # Phase 1: collect all valid dataframes with renamed track columns
    valid_dfs = []
    for filepath, _, video_id in sorted(metric_files):
        df = read_with_header(filepath)
        
        if 'Frame' not in df.columns or 'Time' not in df.columns:
            print(f"Skipping {filepath} (missing Frame/Time)", file=sys.stderr)
            continue

        # Prefix track columns with video_id. If multiple files exist for the same
        # video+metric, include a filename tag to avoid duplicate columns.
        if files_per_video.get(video_id, 0) > 1:
            file_tag = _safe_name(filepath.stem)
            prefix = f"{video_id}_{file_tag}"
        else:
            prefix = video_id

        cols = [c for c in df.columns if c not in ['Frame', 'Time']]
        rename_map = {c: f"{prefix}_{c}" for c in cols}
        df = df.rename(columns=rename_map)
        valid_dfs.append(df)

    if not valid_dfs:
        print(f"No valid data for {key}/{metric}", file=sys.stderr)
        return None

    # Phase 2: check for frame-count differences at the end of recordings
    last_frames = [int(df['Frame'].iloc[-1]) for df in valid_dfs]
    min_last_frame = min(last_frames)
    max_last_frame = max(last_frames)
    frame_diff = max_last_frame - min_last_frame

    if frame_diff > 2:
        print(f"Warning: {key}/{metric}: videos differ by {frame_diff} frames at end "
              f"(trimming to frame {min_last_frame})")

    # Phase 3: merge all dataframes on Frame using an inner join.
    # This naturally drops any trailing frames not present in every file
    # without needing explicit trimming.
    out_df = valid_dfs[0]
    for df in valid_dfs[1:]:
        track_cols = [c for c in df.columns if c not in ['Frame', 'Time']]
        out_df = pd.merge(out_df, df[['Frame'] + track_cols], on='Frame', how='inner')

    if out_df.empty:
        print(f"No valid data for {key}/{metric}", file=sys.stderr)
        return None
    
    # Create output filename
    out_path = out_dir / f"{key}_compiled_{metric}.csv"
    out_df.to_csv(out_path, index=False)
    print(f"Wrote {out_path} (shape={out_df.shape})")
    return out_path

# %%
# Compile all discovered genotypes and write outputs (one file per genotype per metric)
from pathlib import Path
import pandas as pd

if 'compile_tracks_side_by_side' not in globals():
    raise RuntimeError(
        "compile_tracks_side_by_side is not defined. Run Cell 4 (Compile and Export Results function cell) first."
    )

if 'groups' not in globals() or not isinstance(groups, dict):
    if 'find_data_groups' in globals():
        print("`groups` not found. Discovering data groups now...")
        groups = find_data_groups(search_dir)
    else:
        raise RuntimeError(
            "groups is not defined and find_data_groups is unavailable. Run Cell 3 (Setup and File Discovery) first."
        )

if 'out_dir' not in globals():
    current_dir = Path.cwd()
    project_root = current_dir.parent if current_dir.name == "Notebooks" else current_dir
    out_dir = project_root / "data" / "processed"
    out_dir.mkdir(parents=True, exist_ok=True)

results = {}
compilation_rows = []
metadata_rows = []
metrics = ['area', 'length', 'fit', 'curvature']

if not groups:
    print("No data groups found. Nothing to compile.")

for key in sorted(groups.keys()):
    group_data = groups[key]
    files = group_data['files']
    metadata = group_data['metadata']
    date_folder = group_data.get('date')
    genotype = group_data.get('genotype', key)  # Use genotype if available, else use key
    
    results[key] = {}
    
    # Record metadata for summary
    metadata_summary = {'key': key, 'genotype': genotype, 'date': date_folder}
    metadata_summary.update(metadata)
    metadata_rows.append(metadata_summary)
    
    # Compile each metric
    for metric in metrics:
        p = compile_tracks_side_by_side(key, files, metric, out_dir, metadata=metadata)
        if p:
            print(f"Saved compiled file for {key} metric {metric}: {p}")
            compilation_rows.append({
                'key': key, 
                'genotype': genotype, 
                'date': date_folder,
                'metric': metric, 
                'compiled_path': str(p)
            })
            results[key][metric] = p
        else:
            print(f'No {metric} data saved for {key}')

# Create compilation summary
summary = pd.DataFrame(compilation_rows)
display(summary)
summary.to_csv(out_dir / 'compilation_summary.csv', index=False)
print(f'\nWrote compilation summary to {out_dir / "compilation_summary.csv"}')

# Create metadata summary
metadata_df = pd.DataFrame(metadata_rows)
metadata_df.to_csv(out_dir / 'genotype_metadata.csv', index=False)
print(f'Wrote genotype metadata to {out_dir / "genotype_metadata.csv"}')
print(f'\nMetadata columns: {list(metadata_df.columns)}')
# Out:
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_area.csv (shape=(8400, 36))
# Saved compiled file for 260311_wormlab_exports_N2_1050 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_length.csv (shape=(8400, 36))
# Saved compiled file for 260311_wormlab_exports_N2_1050 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_fit.csv (shape=(8400, 36))
# Saved compiled file for 260311_wormlab_exports_N2_1050 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_curvature.csv (shape=(8400, 580))
# Saved compiled file for 260311_wormlab_exports_N2_1050 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_1050_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_area.csv (shape=(8400, 19))
# Saved compiled file for 260311_wormlab_exports_N2_150 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_length.csv (shape=(8400, 19))
# Saved compiled file for 260311_wormlab_exports_N2_150 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_fit.csv (shape=(8400, 19))
# Saved compiled file for 260311_wormlab_exports_N2_150 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_curvature.csv (shape=(8400, 291))
# Saved compiled file for 260311_wormlab_exports_N2_150 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_150_compiled_curvature.csv
# Warning: 260311_wormlab_exports_N2_21/area: videos differ by 6 frames at end (trimming to frame 8395)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_area.csv (shape=(8395, 23))
# Saved compiled file for 260311_wormlab_exports_N2_21 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_area.csv
# Warning: 260311_wormlab_exports_N2_21/length: videos differ by 6 frames at end (trimming to frame 8395)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_length.csv (shape=(8395, 23))
# Saved compiled file for 260311_wormlab_exports_N2_21 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_length.csv
# Warning: 260311_wormlab_exports_N2_21/fit: videos differ by 6 frames at end (trimming to frame 8395)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_fit.csv (shape=(8395, 23))
# Saved compiled file for 260311_wormlab_exports_N2_21 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_fit.csv
# Warning: 260311_wormlab_exports_N2_21/curvature: videos differ by 6 frames at end (trimming to frame 8395)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_curvature.csv (shape=(8395, 359))
# Saved compiled file for 260311_wormlab_exports_N2_21 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_21_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_area.csv (shape=(8400, 21))
# Saved compiled file for 260311_wormlab_exports_N2_250 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_length.csv (shape=(8400, 21))
# Saved compiled file for 260311_wormlab_exports_N2_250 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_fit.csv (shape=(8400, 21))
# Saved compiled file for 260311_wormlab_exports_N2_250 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_curvature.csv (shape=(8400, 325))
# Saved compiled file for 260311_wormlab_exports_N2_250 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_250_compiled_curvature.csv
# Warning: 260311_wormlab_exports_N2_350/area: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_area.csv (shape=(8396, 20))
# Saved compiled file for 260311_wormlab_exports_N2_350 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_area.csv
# Warning: 260311_wormlab_exports_N2_350/length: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_length.csv (shape=(8396, 20))
# Saved compiled file for 260311_wormlab_exports_N2_350 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_length.csv
# Warning: 260311_wormlab_exports_N2_350/fit: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_fit.csv (shape=(8396, 20))
# Saved compiled file for 260311_wormlab_exports_N2_350 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_fit.csv
# Warning: 260311_wormlab_exports_N2_350/curvature: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_curvature.csv (shape=(8396, 308))
# Saved compiled file for 260311_wormlab_exports_N2_350 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_350_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_area.csv (shape=(8400, 32))
# Saved compiled file for 260311_wormlab_exports_N2_450 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_length.csv (shape=(8400, 32))
# Saved compiled file for 260311_wormlab_exports_N2_450 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_fit.csv (shape=(8400, 32))
# Saved compiled file for 260311_wormlab_exports_N2_450 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_curvature.csv (shape=(8400, 512))
# Saved compiled file for 260311_wormlab_exports_N2_450 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_450_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_area.csv (shape=(8400, 14))
# Saved compiled file for 260311_wormlab_exports_N2_550 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_length.csv (shape=(8400, 14))
# Saved compiled file for 260311_wormlab_exports_N2_550 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_fit.csv (shape=(8400, 14))
# Saved compiled file for 260311_wormlab_exports_N2_550 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_curvature.csv (shape=(8400, 206))
# Saved compiled file for 260311_wormlab_exports_N2_550 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_550_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_area.csv (shape=(8400, 55))
# Saved compiled file for 260311_wormlab_exports_N2_650 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_length.csv (shape=(8400, 55))
# Saved compiled file for 260311_wormlab_exports_N2_650 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_fit.csv (shape=(8400, 55))
# Saved compiled file for 260311_wormlab_exports_N2_650 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_curvature.csv (shape=(8400, 903))
# Saved compiled file for 260311_wormlab_exports_N2_650 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_650_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_area.csv (shape=(8400, 21))
# Saved compiled file for 260311_wormlab_exports_N2_750 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_length.csv (shape=(8400, 21))
# Saved compiled file for 260311_wormlab_exports_N2_750 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_fit.csv (shape=(8400, 21))
# Saved compiled file for 260311_wormlab_exports_N2_750 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_curvature.csv (shape=(8400, 325))
# Saved compiled file for 260311_wormlab_exports_N2_750 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_750_compiled_curvature.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_area.csv (shape=(8400, 24))
# Saved compiled file for 260311_wormlab_exports_N2_850 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_area.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_length.csv (shape=(8400, 24))
# Saved compiled file for 260311_wormlab_exports_N2_850 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_length.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_fit.csv (shape=(8400, 24))
# Saved compiled file for 260311_wormlab_exports_N2_850 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_fit.csv
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_curvature.csv (shape=(8400, 376))
# Saved compiled file for 260311_wormlab_exports_N2_850 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_850_compiled_curvature.csv
# Warning: 260311_wormlab_exports_N2_950/area: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_area.csv (shape=(8396, 32))
# Saved compiled file for 260311_wormlab_exports_N2_950 metric area: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_area.csv
# Warning: 260311_wormlab_exports_N2_950/length: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_length.csv (shape=(8396, 32))
# Saved compiled file for 260311_wormlab_exports_N2_950 metric length: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_length.csv
# Warning: 260311_wormlab_exports_N2_950/fit: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_fit.csv (shape=(8396, 32))
# Saved compiled file for 260311_wormlab_exports_N2_950 metric fit: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_fit.csv
# Warning: 260311_wormlab_exports_N2_950/curvature: videos differ by 5 frames at end (trimming to frame 8396)
# Wrote c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_curvature.csv (shape=(8396, 512))
# Saved compiled file for 260311_wormlab_exports_N2_950 metric curvature: c:\Users\MBF\celegans-volume-analysis\data\processed\260311_wormlab_exports_N2_950_compiled_curvature.csv
#                                key                        genotype  date  \
# 0   260311_wormlab_exports_N2_1050  260311_wormlab_exports_N2_1050  None
# 1   260311_wormlab_exports_N2_1050  260311_wormlab_exports_N2_1050  None
# 2   260311_wormlab_exports_N2_1050  260311_wormlab_exports_N2_1050  None
# 3   260311_wormlab_exports_N2_1050  260311_wormlab_exports_N2_1050  None
# 4    260311_wormlab_exports_N2_150   260311_wormlab_exports_N2_150  None
# 5    260311_wormlab_exports_N2_150   260311_wormlab_exports_N2_150  None
# 6    260311_wormlab_exports_N2_150   260311_wormlab_exports_N2_150  None
# 7    260311_wormlab_exports_N2_150   260311_wormlab_exports_N2_150  None
# 8     260311_wormlab_exports_N2_21    260311_wormlab_exports_N2_21  None
# 9     260311_wormlab_exports_N2_21    260311_wormlab_exports_N2_21  None
# 10    260311_wormlab_exports_N2_21    260311_wormlab_exports_N2_21  None
# 11    260311_wormlab_exports_N2_21    260311_wormlab_exports_N2_21  None
# 12   260311_wormlab_exports_N2_250   260311_wormlab_exports_N2_250  None
# 13   260311_wormlab_exports_N2_250   260311_wormlab_exports_N2_250  None
# 14   260311_wormlab_exports_N2_250   260311_wormlab_exports_N2_250  None
# 15   260311_wormlab_exports_N2_250   260311_wormlab_exports_N2_250  None
# 16   260311_wormlab_exports_N2_350   260311_wormlab_exports_N2_350  None
# 17   260311_wormlab_exports_N2_350   260311_wormlab_exports_N2_350  None
# 18   260311_wormlab_exports_N2_350   260311_wormlab_exports_N2_350  None
# 19   260311_wormlab_exports_N2_350   260311_wormlab_exports_N2_350  None
# 20   260311_wormlab_exports_N2_450   260311_wormlab_exports_N2_450  None
# 21   260311_wormlab_exports_N2_450   260311_wormlab_exports_N2_450  None
# 22   260311_wormlab_exports_N2_450   260311_wormlab_exports_N2_450  None
# 23   260311_wormlab_exports_N2_450   260311_wormlab_exports_N2_450  None
# 24   260311_wormlab_exports_N2_550   260311_wormlab_exports_N2_550  None
# 25   260311_wormlab_exports_N2_550   260311_wormlab_exports_N2_550  None
# 26   260311_wormlab_exports_N2_550   260311_wormlab_exports_N2_550  None
# 27   260311_wormlab_exports_N2_550   260311_wormlab_exports_N2_550  None
# 28   260311_wormlab_exports_N2_650   260311_wormlab_exports_N2_650  None
# 29   260311_wormlab_exports_N2_650   260311_wormlab_exports_N2_650  None
# 30   260311_wormlab_exports_N2_650   260311_wormlab_exports_N2_650  None
# 31   260311_wormlab_exports_N2_650   260311_wormlab_exports_N2_650  None
# 32   260311_wormlab_exports_N2_750   260311_wormlab_exports_N2_750  None
# 33   260311_wormlab_exports_N2_750   260311_wormlab_exports_N2_750  None
# 34   260311_wormlab_exports_N2_750   260311_wormlab_exports_N2_750  None
# 35   260311_wormlab_exports_N2_750   260311_wormlab_exports_N2_750  None
# 36   260311_wormlab_exports_N2_850   260311_wormlab_exports_N2_850  None
# 37   260311_wormlab_exports_N2_850   260311_wormlab_exports_N2_850  None
# 38   260311_wormlab_exports_N2_850   260311_wormlab_exports_N2_850  None
# 39   260311_wormlab_exports_N2_850   260311_wormlab_exports_N2_850  None
# 40   260311_wormlab_exports_N2_950   260311_wormlab_exports_N2_950  None
# 41   260311_wormlab_exports_N2_950   260311_wormlab_exports_N2_950  None
# 42   260311_wormlab_exports_N2_950   260311_wormlab_exports_N2_950  None
# 43   260311_wormlab_exports_N2_950   260311_wormlab_exports_N2_950  None
#
#        metric                                      compiled_path
# 0        area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 1      length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 2         fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 3   curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 4        area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 5      length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 6         fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 7   curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 8        area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 9      length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 10        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 11  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 12       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 13     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 14        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 15  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 16       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 17     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 18        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 19  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 20       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 21     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 22        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 23  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 24       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 25     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 26        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 27  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 28       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 29     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 30        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 31  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 32       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 33     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 34        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 35  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 36       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 37     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 38        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 39  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 40       area  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 41     length  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 42        fit  c:\Users\MBF\celegans-volume-analysis\data\pro...
# 43  curvature  c:\Users\MBF\celegans-volume-analysis\data\pro...
# Wrote compilation summary to c:\Users\MBF\celegans-volume-analysis\data\processed\compilation_summary.csv
# Wrote genotype metadata to c:\Users\MBF\celegans-volume-analysis\data\processed\genotype_metadata.csv
#
# Metadata columns: ['key', 'genotype', 'date']

# %% [markdown]
# ## Notes
#
# **Data structure:**
# ```
# data/raw/
#   <date_folder>/                     (e.g., 260311/)
#     <genotype_or_intermediary>/
#       <condition>/                   (e.g., 150/, 250/)
#         0001/                        (video folder)
#           area.csv
#           length.csv
#           position.csv
#           fit.csv
#           curvature.csv / CurvatureMap_Track_N.csv / BatchExport.csv_Curvature MapTrack_N.csv
#         0002/                        (another video)
#           ...
#
# data/metadata/
#   150.yaml                           (one YAML per condition, named to match the condition folder)
#   250.yaml
#   ...
# ```
#
# **Output files:**
# - `<group_key>_compiled_<metric>.csv`: Compiled metric data with tracks from all videos side-by-side
# - `compilation_summary.csv`: List of all compiled files with group key and paths
# - `genotype_metadata.csv`: Metadata from all YAML files with group information
#
# **Column naming:**
# - Track columns in output are prefixed with video_id to distinguish videos (e.g., `0001_track_name`)
# - When a video has multiple curvature files, the filename is included in the prefix (e.g., `0001_CurvatureMap_Track_1_<col>`)
#
# **YAML metadata lookup (search order):**
# 1. `data/metadata/<condition_folder_name>.yaml`  — centralised location (preferred)
# 2. Any `*.yaml` / `*.yml` file inside the condition folder itself (legacy fallback)
#
# **Metric CSV naming (supported):**
# - Legacy metric filenames: `area.csv`, `length.csv`, `position.csv`, `fit.csv`, `curvature.csv`
# - WormLab batch-export filenames: `BatchExport.csv_Position.csv`, `BatchExport.csv_Area.csv`, `BatchExport.csv_Length.csv`, `BatchExport.csv_Fit.csv`, `BatchExport.csv_Curvature MapTrack_N.csv`
# - Curvature aliases also recognized: `CurvatureMap_Track_N.csv`, `spinecurvature`, `spine_curvature`, `wormspinecurvature`, `worm_spine_curvature`
# - Metric detection is case-insensitive and matches metric tokens anywhere in the filename
#
# **Handling different video lengths:**
# - If videos have different numbers of frames, the compiled file includes ALL frames from ALL videos
# - Track values are filled with NaN where a video doesn't have data for that frame
#
# **Backward compatibility:**
# - The code also supports YAML files placed directly in the condition folder (legacy)
