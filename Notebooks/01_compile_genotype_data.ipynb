# %% [markdown]
# # Genotype Data Compilation
#
# This notebook compiles raw data organized by genotype/group and video into standardized CSV files with side-by-side track columns for each metric (area, length, position, fit).

# %%
from pathlib import Path
import pandas as pd
import re
import sys
import yaml

# Data folder structure:
# data/raw/
#   <genotype_or_group>/
#     config.yaml  (metadata file)
#     0001/  (video folder)
#       position.csv, length.csv, area.csv, fit.csv
#     0002/  (another video)
#       ...
raw_dir = Path("data/raw")
compiled_dir = Path("data/processed")
raw_dir.mkdir(parents=True, exist_ok=True)
compiled_dir.mkdir(parents=True, exist_ok=True)

search_dir = raw_dir
out_dir = compiled_dir

# Metadata file name in each genotype folder
METADATA_FILE = "config.yaml"


def load_genotype_metadata(genotype_dir: Path):
    """Load metadata from config.yaml in genotype folder.
    Returns a dict with metadata, or empty dict if file not found.
    """
    metadata_path = genotype_dir / METADATA_FILE
    if not metadata_path.exists():
        return {}
    
    try:
        with open(metadata_path, 'r') as f:
            metadata = yaml.safe_load(f)
        return metadata if metadata else {}
    except Exception as e:
        print(f'Warning reading {metadata_path}: {e}', file=sys.stderr)
        return {}


def gather_files(dirpath: Path):
    """
    Gather metric files organized by genotype/group and video folder.
    Also loads metadata from config.yaml in each genotype folder.
    Returns a dict: {genotype: {'files': [(filepath, metric, video_id), ...], 'metadata': {...}}}
    """
    groups = {}
    if not dirpath.exists():
        return groups
    
    # Iterate through genotype/group folders
    for genotype_dir in sorted(dirpath.iterdir()):
        if not genotype_dir.is_dir():
            continue
        genotype = genotype_dir.name
        
        # Load metadata for this genotype
        metadata = load_genotype_metadata(genotype_dir)
        
        files_list = []
        # Iterate through video folders (0001, 0002, etc.)
        for video_dir in sorted(genotype_dir.iterdir()):
            if not video_dir.is_dir():
                continue
            video_id = video_dir.name
            
            # Find CSV files in video folder
            for f in video_dir.glob('*.csv'):
                metric = f.stem  # e.g., 'position', 'length', 'area', 'fit'
                files_list.append((f, metric, video_id))
        
        groups[genotype] = {
            'files': files_list,
            'metadata': metadata
        }
    
    return groups


def compile_tracks_side_by_side(genotype: str, files_metrics, metric_keyword: str, out_dir: Path, metadata: dict = None):
    """Combine CSVs for a given metric by placing all track columns side-by-side.
    Produces a single file per genotype per metric (e.g., genotype_compiled_area.csv).
    files_metrics: list of (filepath, metric, video_id) tuples
    metadata: optional dict of genotype metadata to include as comments
    """
    metric_files = [(f, metric, vid) for f, metric, vid in files_metrics if metric_keyword.lower() in metric.lower()]
    if not metric_files:
        return None

    ref_ft = None
    tracks_list = []

    for f, metric, video_id in sorted(metric_files):
        try:
            df = pd.read_csv(f, skiprows=1)
        except Exception as e:
            print(f'Warning reading {f}: {e}', file=sys.stderr)
            continue

        if 'Frame' not in df.columns or 'Time' not in df.columns:
            print(f'Warning: {f} missing Frame/Time columns', file=sys.stderr)
            continue

        ft = df[['Frame', 'Time']].reset_index(drop=True)
        if ref_ft is None:
            ref_ft = ft
        else:
            if not (ft['Frame'].equals(ref_ft['Frame']) and ft['Time'].equals(ref_ft['Time'])):
                print(f'Warning: Frame/Time mismatch in {f}', file=sys.stderr)

        # track columns are all columns except Frame and Time
        track_cols = [c for c in df.columns if c not in ('Frame', 'Time')]
        if not track_cols:
            continue

        # make unique column names by prefixing with video_id to distinguish videos
        renamed = {c: f"{video_id}_{c}" for c in track_cols}
        tracks = df[track_cols].rename(columns=renamed).reset_index(drop=True)

        tracks_list.append(tracks)

    if not tracks_list or ref_ft is None:
        return None

    # concatenate all track columns side-by-side
    all_tracks = pd.concat(tracks_list, axis=1)
    out_df = pd.concat([ref_ft, all_tracks], axis=1)

    # Ensure Frame and Time are first columns
    cols = list(out_df.columns)
    ordered = []
    for c in ['Frame', 'Time']:
        if c in cols:
            ordered.append(c)
            cols.remove(c)
    ordered.extend(cols)
    out_df = out_df[ordered]

    safe_metric = re.sub(r"[^0-9A-Za-z_-]", "_", metric_keyword.lower())
    out_path = out_dir / f"{genotype}_compiled_{safe_metric}.csv"
    out_df.to_csv(out_path, index=False)
    return out_path


# Inspect available files and groups
groups = gather_files(search_dir)
print(f'Raw data dir: {search_dir}')
print(f'Output dir: {out_dir}')
print(f'Found {len(groups)} genotypes: {sorted(groups.keys())}')
print(f'\nMetadata summary:')
for genotype in sorted(groups.keys()):
    metadata = groups[genotype]['metadata']
    if metadata:
        print(f'  {genotype}:')
        for key, value in metadata.items():
            print(f'    {key}: {value}')
    else:
        print(f'  {genotype}: (no config.yaml found)')
# Out:
# Raw data dir: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\raw
# Output dir: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled
# Found 6 genotypes: ['N2', 'dr170', 'dr170_dr180', 'dr180', 'osm6_p811', 'p811_dr170']

# %% [markdown]
# ## Setup and File Discovery
#
# Define input/output directories and helper functions to:
# - Discover genotype/group folders in `data/raw`
# - Load metadata from `config.yaml` in each genotype folder (containing strain, genotype, NaCl concentration, frame rate, pixel resolution, notes)
# - Find video folders (0001, 0002, etc.) within each genotype
# - Gather metric CSV files (position, length, area, fit) from each video folder
# - Compile tracks side-by-side with consistent Frame and Time columns
# - Display a summary of all loaded metadata

# %%
# Compile all discovered genotypes and write outputs (one file per genotype per metric)
results = {}
compilation_rows = []
metadata_rows = []
metrics = ['area', 'length', 'fit']

for g in sorted(groups.keys()):
    files = groups[g]['files']
    metadata = groups[g]['metadata']
    results[g] = {}
    
    # Record metadata for summary
    metadata_summary = {'genotype': g}
    metadata_summary.update(metadata)
    metadata_rows.append(metadata_summary)
    
    # Compile each metric
    for metric in metrics:
        p = compile_tracks_side_by_side(g, files, metric, out_dir, metadata=metadata)
        if p:
            print(f"Saved compiled file for {g} metric {metric}: {p}")
            compilation_rows.append({'genotype': g, 'metric': metric, 'compiled_path': str(p)})
            results[g][metric] = p
        else:
            print(f'No {metric} data saved for {g}')

# Create compilation summary
summary = pd.DataFrame(compilation_rows)
display(summary)
summary.to_csv(out_dir / 'compilation_summary.csv', index=False)
print(f'\nWrote compilation summary to {out_dir / "compilation_summary.csv"}')

# Create metadata summary
metadata_df = pd.DataFrame(metadata_rows)
metadata_df.to_csv(out_dir / 'genotype_metadata.csv', index=False)
print(f'Wrote genotype metadata to {out_dir / "genotype_metadata.csv"}')
print(f'\nMetadata columns: {list(metadata_df.columns)}')
# Out:
# Saved compiled file for N2 metric WT 550 0003 Area: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled\N2_compiled_WT_550_0003_Area.csv
# Saved compiled file for N2 metric WT 550 0003 Fit: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled\N2_compiled_WT_550_0003_Fit.csv
# Saved compiled file for N2 metric WT 550 0003 Length: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled\N2_compiled_WT_550_0003_Length.csv
# Saved compiled file for N2 metric WT 550 0003 Width: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled\N2_compiled_WT_550_0003_Width.csv
# Saved compiled file for N2 metric WT2 5500001 Fit: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled\N2_compiled_WT2_5500001_Fit.csv
# Saved compiled file for N2 metric WT2 5500001 Length-1: E:\Todd\OSR\251128\OSR compiled data all genotypes\data\compiled\N2_compiled_WT2_5500001_Length-1.csv
# ...

# %% [markdown]
# ## Compile and Export Results
#
# Process all discovered genotypes and metrics:
# - Compile CSVs for each metric (area, length, fit)
# - Generate one output file per genotype per metric
# - Create a compilation summary CSV listing all compiled files and their locations
# - Create a genotype metadata summary CSV combining all config.yaml metadata (strain, genotype, NaCl, frame rate, pixel resolution, notes, etc.)

# %% [markdown]
# ## Notes
#
# **Data structure:**
# ```
# data/raw/
#   <genotype>/
#     config.yaml        (metadata file with strain, genotype, NaCl, frame_rate, pixel_resolution, notes, etc.)
#     0001/              (video folder)
#       area.csv
#       length.csv
#       position.csv
#       fit.csv
#     0002/              (another video)
#       ...
# ```
#
# **Output files:**
# - `<genotype>_compiled_<metric>.csv`: Compiled metric data with tracks from all videos side-by-side
# - `compilation_summary.csv`: List of all compiled files and their paths
# - `genotype_metadata.csv`: Metadata from all genotype config.yaml files
#
# **Column naming:**
# - Track columns in output are prefixed with video_id to distinguish videos (e.g., `0001_track_name`)
